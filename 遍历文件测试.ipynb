# %%
import os

# %%
cwd = os.getcwd()

# %%
for i in os.walk(cwd):
    print i
# Out:
# ('F:\\data', ['.ipynb_checkpoints', 'test_file0', 'test_file1', 'test_file2'], ['Arr.vn', 'bayesTextClassification.py', 'bayesTextCls.py', 'bayesTextCls.pyc', 'bayesTextCls_0.82.py', 'bayesTextCls_0.py', 'bayesTextCls_1.py', 'decisionTreeTest.py', 'famale.txt', 'jiebaCutTest.wpr', 'jiebaCutTest.wpu', 'jiebaTest.py', 'male.txt', 'mongo.zip', 'ones.txt', 'ones_.txt', 'tf-idf.ipynb', 'tfidf_test.py', 'twos.txt', 'twos_.txt', 'Untitled.ipynb', 'Untitled1.ipynb', 'zeros.txt', '\xb1\xe9\xc0\xfa\xce\xc4\xbc\xfe\xb2\xe2\xca\xd4.ipynb'])
# ('F:\\data\\.ipynb_checkpoints', [], ['tf-idf-checkpoint.ipynb', 'Untitled-checkpoint.ipynb', 'Untitled1-checkpoint.ipynb', '\xb1\xe9\xc0\xfa\xce\xc4\xbc\xfe\xb2\xe2\xca\xd4-checkpoint.ipynb'])
# ('F:\\data\\test_file0', [], ['\xbf\xce\xb3\xcc.csv', '\xc1\xbf\xbb\xaf.csv'])
# ('F:\\data\\test_file1', [], ['\xb1\xa3\xcf\xd5-372.csv', '\xd6\xa4\xc8\xaf-394.csv', '\xbd\xf0\xc8\xda-5.csv', '\xd2\xf8\xd0\xd0-143.csv'])
# ...

# %%
for root, dirs, files in os.walk(cwd+'\\test_file2'):
    for j in files:
        print root + j
# Out:
# F:\data\test_file2\��ͨ4150.txt
# F:\data\test_file2\��ͨ4151.txt
# F:\data\test_file2\��ͨ4152.txt
# F:\data\test_file2\��ͨ4153.txt
# F:\data\test_file2\��ͨ4154.txt
# F:\data\test_file2\��ͨ4155.txt
# F:\data\test_file2\��ͨ4156.txt
# F:\data\test_file2\��ͨ4157.txt
# F:\data\test_file2\��ͨ4158.txt
# F:\data\test_file2\��ͨ4159.txt
# F:\data\test_file2\��ͨ4160.txt
# F:\data\test_file2\��ͨ4161.txt
# F:\data\test_file2\��ͨ4162.txt
# F:\data\test_file2\��ͨ4163.txt
# F:\data\test_file2\��ͨ4164.txt
# F:\data\test_file2\��ͨ4165.txt
# F:\data\test_file2\��ͨ4166.txt
# F:\data\test_file2\��ͨ4167.txt
# F:\data\test_file2\��ͨ4168.txt
# F:\data\test_file2\��ͨ4169.txt
# F:\data\test_file2\��ͨ4170.txt
# F:\data\test_file2\��ͨ4171.txt
# F:\data\test_file2\��ͨ4172.txt
# F:\data\test_file2\��ͨ4173.txt
# F:\data\test_file2\��ͨ4174.txt
# F:\data\test_file2\��ͨ4175.txt
# F:\data\test_file2\��ͨ4176.txt
# F:\data\test_file2\��ͨ4177.txt
# F:\data\test_file2\��ͨ4178.txt
# F:\data\test_file2\��ͨ4193.txt
# ...

# %%
rets = []
for root, dirs, files in os.walk(cwd+'\\test_file2'):
    if not dirs:
        for fn in files:
            rets.append((root+fn, root[-4:]))

# %%
print u'\u7684'
# Out:
# 的

# %%
f = open('F:\\data\\test_file2\\\xd2\xd5\xca\xf5\\2243.txt')

# %%
for i in f.readlines():
    print i
# Out:
# ��������ʮ�塱�ڼ��Ļ���ҵ��չ�ƻ�
#
#
#
#
#
#
#
# һ�������塱ʱ���Ļ���ҵ�ɼ�ϲ��
#
#
#
# �����塱ʱ������ί�����������쵼�£��Ӵ����Ļ���ҵ�ĸĸ����ȣ�Ⱥ���Ļ����������������ﱣ�������ο������Ļ��г������淢չѸ�٣�ȡ���˿�ϲ�ĳɾ͡�
#
#
#
# ��һ��Ⱥ���Ļ���ҵ���չ
#
#
#
#     1��1998��7�£�������Ͷ��480��Ԫ������3200ƽ���׵Ļ���·�Ļ��㳡���ۼ�144���˲μ��˹㳡���ͬʱ���ɿ��ŵ�3000ƽ���׺����Ļ��㳡��Ч�شٽ�������������Ⱥ���Ļ���Ŀ�չ��
#
#
#
# 2�������ٰ�Ĵ��԰��¥���ͱ��������Ļ������ڣ�Ϊ��Ծ�������񶬼����ļ����Ļ�����������˾޴�����ã�̽������һ���ʺ�������ɫ���ġ��̡��ý�ϵ�Ⱥ��֮·��
#
#
#
# 3������ͼ��ݱ���Ϊ����һ���ݣ�ʵ����ͼ����ĵ����绯����ÿ��Ӵ�һ����˴Σ�������Ͷ��25��Ԫ�����˵��ԣ��������˵��������ҡ�
#
#
#
# 4��1997��������Ͷ��60����Ԫ����ȫ��60%�ľӣ��ң�ί�Ὠ����216���Ļ�������ң�ʹ30����������棬�ƶ���ȫ�������������蹤���ķ�չ��
#
#
#
# 5������ί�����������쵼����������Ļ���ѡַ���������ƹ�����Ϊ���Ļ��ݵĽ���춨�˻�����
#
#
#
# 6����������ӰƬ��ӳ�»��㣬ÿ���ӳ40-50���Σ��ۼ��޳���ӳ��Ӱ200�ೡ�����ڴ�40�����˴Ρ�
#
#
#
# �����������ݳ�����һ��¥
#
#
#
# �Ƴ���Ϸ���������ˣ��߳���·�ǡ����塱�ڼ����������г���һ����ɫ��
#
#
#
# ...
